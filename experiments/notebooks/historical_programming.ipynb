# %%
# %load_ext autoreload 
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
from cts_recommender.settings import get_settings
from cts_recommender.io import readers

cfg = get_settings()

# %%
catalog_df = readers.read_parquet(cfg.processed_dir / "whatson_catalogue.parquet")
catalog_df
# Out:
#        collection                 title original_title  duration  \
# 104     Beethoven             Beethoven      Beethoven  01:23:10
# 123    Box office                 Intro           None  00:00:00
# 124    Box office  Presentation de taxi           None  00:00:00
# 126    Box office       Intro 1/intro 2           None  00:00:00
# 386        Cinéma               Rosetta           None  01:30:06
# ...           ...                   ...            ...       ...
# 17178    Téléfilm               Gothard           None  00:00:55
# 17179    Téléfilm                Salomé           None  01:26:26
# 17180    Téléfilm      La reine de Saba           None  01:33:30
# 17181    Téléfilm   Françoise et Udo...           None  01:06:52
# 17182    Téléfilm  Ni figue, ni raisin            None  00:42:57
#
#                                        short_description  \
# 104                                                 None
# 123                                                 None
# ...
